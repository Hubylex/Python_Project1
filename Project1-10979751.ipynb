# %% [markdown]
# # NAME : lAMPTEY HUBERT
# # ID   : 10979751
# # DEPARTMENT : AGRICULTURAL ENGINEERING

# %% [markdown]
# Firstly, all libraries needed for the project are imported

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# To get relevant information about the data, we use this....

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# The Number of null values in each column is given by:
# ---
# |   |ID |fixed acidity|	volatile acidity|	citric acid |residual sugar|chlorides|free sulfur dioxide|total sulfur dioxide|density|pH  |sulphates|alcohol|qualitY|
# |---|---|  ---        |  ---             |       ---    |---           |---      |---                |---                 |---    |--- |---      |---    |---    |
# |   | 0  |  1          |  0               |           1  |0             |3        |1                  |1                   |1      |1   |0        |0      |1      |

# %% [markdown]
# ### Getting rid of the null values by replacing them in each column by the MEAN VALUES
# The mean was used to replace the null values because the data is normally distributed. The mean is a good choice when the data is evenly distributed around the center and there are no extreme values pulling the mean in one direction or another.And in this case of data it is.

# %% [markdown]
# - Calculating mean values for each column

# %%
mean_c1 = data['ID'].mean().round(2)
mean_c2 = data['fixed acidity'].mean().round(2)
mean_c3 = data['volatile acidity'].mean().round(2)
mean_c4 = data['citric acid'].mean().round(2)
mean_c5 = data['residual sugar'].mean().round(2)
mean_c6 = data['chlorides'].mean().round(2)
mean_c7 = data['free sulfur dioxide'].mean().round(2)
mean_c8 = data['total sulfur dioxide'].mean().round(2)
mean_c9 = data['density'].mean().round(2)
mean_c10 = data['pH'].mean().round(2)
mean_c11 = data['sulphates'].mean().round(2)
mean_c12 = data['alcohol'].mean().round(2)
mean_c13 = data['quality'].mean().round(2)

# %% [markdown]
# - Replacing the null values in each column by the MEAN VALUES

# %%
data['ID'] = data['ID'].fillna(mean_c1)
data['fixed acidity'] = data['fixed acidity'].fillna(mean_c2)
data['volatile acidity'] = data['volatile acidity'].fillna(mean_c3)
data['citric acid'] = data['citric acid'].fillna(mean_c4)
data['residual sugar'] = data['residual sugar'].fillna(mean_c5)
data['chlorides'] = data['chlorides'].fillna(mean_c6)
data['free sulfur dioxide'] = data['free sulfur dioxide'].fillna(mean_c7)
data['total sulfur dioxide'] = data['total sulfur dioxide'].fillna(mean_c8)
data['density'] = data['density'].fillna(mean_c9)
data['pH'] = data['pH'].fillna(mean_c10)
data['sulphates'] = data['sulphates'].fillna(mean_c11)
data['alcohol'] = data['alcohol'].fillna(mean_c12)
data['quality'] = data['quality'].fillna(mean_c13)

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
data = data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 175.1 KB

# %% [markdown]
# ### STATISTICAL INFERENCES FOR ENTIRE DATASET

# %%
data.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271174
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087492            15.886877             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %% [markdown]
# ### STATISTICAL INFERENCES FOR INDIVIDUAL COLUMNS IN THE DATASET

# %%
columns = ['ID', 'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
for column in columns:
    print(data[columns].describe())
    print('\n')
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271174
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087492            15.886877             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %% [markdown]
# ### DATA CORRELATION AMONG CLOUMNS

# %%
data_corr = data.corr().round(2)

# %%
data_corr
# Out:
#                         ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.00          -0.27             -0.01        -0.15
# fixed acidity        -0.27           1.00             -0.26         0.67
# volatile acidity     -0.01          -0.26              1.00        -0.55
# citric acid          -0.15           0.67             -0.55         1.00
# residual sugar       -0.03           0.11              0.00         0.14
# chlorides            -0.12           0.09              0.06         0.20
# free sulfur dioxide   0.09          -0.15             -0.01        -0.06
# total sulfur dioxide -0.11          -0.11              0.08         0.04
# density              -0.37           0.67              0.02         0.36
# pH                    0.14          -0.68              0.24        -0.54
# sulphates            -0.12           0.18             -0.26         0.31
# alcohol               0.25          -0.06             -0.20         0.11
# ...

# %% [markdown]
# From the correlation data, the quality of the wine normally increase as the various factors increases;fixed acidity,citric acid,residual sugar and so on.

# %% [markdown]
# ## HEAT MAPS

# %%
sns.heatmap(data_corr,cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# ### HIDDEN INFERENCES FROM THE HEATMAP DIAGRAM
#
# 1. The heatmap diagram easily displays the correlation strength between the columns. Dark blue color indicates a strong positive correlation, while lighter shades of blue signify weaker correlations, approaching negative.
# 2. Each column displays a maximum positive correlation of 1 against itself, which is expected as the values are identical.
# 3. The correlation between fixed acidity and pH is minimal, as evidenced by the light color in their correlation.
# 4. The correlation between free sulfur dioxide and total sulfur dioxide is strong, as depicted by the deep blue color in their correlation.

# %% [markdown]
# ###  PIE CAHRT

# %%
MeanValues=[mean_c2,mean_c3,mean_c4,mean_c5,mean_c6,mean_c7,mean_c8,mean_c9,mean_c10,mean_c11,mean_c12,mean_c13]
MeanLabels=['FixedAcidity','VolatileAcidity','CitricACid','ResidualSugar','Chlorides','FreeSulfurDioxide','TotalSulfurDioxide',
            'Density','pH','Sulphates','alcohol','quality']
plt.pie(MeanValues,startangle=90,autopct='%1.2f',labels= MeanLabels, explode=(0,2,0,4,1,0,1,2,3,0,0,0))

plt.show()

# %% [markdown]
# From the pie chart above, it can be observed  that in comparison of the columns of the dataset, the mean of total Sulfur Dioxide occupies the largest portion of the chart with the chlorides occupying the least portion of the chart

# %% [markdown]
# ### BAR CHART

# %%
hist_plot=data['free sulfur dioxide'].hist(bins=9)
hist_plot.set_xlabel('amount of the free sulfur dioxide')
hist_plot.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
hist_plot=data['total sulfur dioxide'].hist(bins=9)
hist_plot.set_xlabel('amount of the total sulfur dioxide')
hist_plot.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
hist_plot=data['alcohol'].hist(bins=9)
hist_plot.set_xlabel('amount of alcohol')
hist_plot.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
hist_plot=data['fixed acidity'].hist(bins=9)
hist_plot.set_xlabel('amount of the Fixed acidity')
hist_plot.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# These are bar charts representing the frequency of the amount of a few products(fixed acidity,alcohol,total sulpure dioxide,free sulpure dioxide) in the entire data set.
